# %% [markdown]
# ## Strings

# %%
## Replace part of the string

my_text = "Hello, my name's George."

my_text = my_text.replace("George", "John")
my_text
# Out:
# "Hello, my name's John."

# %% [markdown]
# ## FUNCTIONS

# %%
### Write a function to calculate and return the square of a number

def square_of_num(num):
    return num ** 2

result = square_of_num(5)
print(result)
# Out:
# 25

# %%
### Create a functions that takes two numbers as parameters and returns their sum
